# %%
import pandas as pd
import numpy as np
import pandas_ta as ta

# %%
import yfinance as yf

# %%
nifty = yf.download('^NSEI',period='max',interval='1d')
banknifty=yf.download('^NSEBANK',period='max',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
nifty.head(3)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098  4732.350098
#
#             Volume
# Date
# 2007-09-17       0
# 2007-09-18       0
# 2007-09-19       0

# %%
banknifty.head(3)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-09-17  6898.000000  6977.200195  6843.000000  6897.100098  6897.020020
# 2007-09-18  6921.149902  7078.950195  6883.600098  7059.649902  7059.567871
# 2007-09-19  7111.000000  7419.350098  7111.000000  7401.850098  7401.764160
#
#             Volume
# Date
# 2007-09-17       0
# 2007-09-18       0
# 2007-09-19       0

# %%
data_frame=nifty["Close"]

# %%
temp=pd.merge(nifty["Close"],banknifty["Close"])

# %%
temp.head()
# Out:
#          Close
# 0  5512.149902
# 1  5538.750000
# 2  5284.200195
# 3  5495.100098
# 4  5999.350098

# %%
cdf=pd.DataFrame(columns=['nf','bnf'])
cdf['nf']=nifty['Close']
cdf['bnf']=banknifty['Close']
cdf.index=nifty.index

# %%
cdf
# Out:
#                       nf           bnf
# Date
# 2007-09-17   4494.649902   6897.100098
# 2007-09-18   4546.200195   7059.649902
# 2007-09-19   4732.350098   7401.850098
# 2007-09-20   4747.549805   7390.149902
# 2007-09-21   4837.549805   7464.500000
# ...                  ...           ...
# 2023-09-26  19664.699219  44624.199219
# 2023-09-27  19716.449219  44588.300781
# 2023-09-28  19523.550781  44300.949219
# 2023-09-29  19638.300781  44584.550781
# 2023-10-03  19528.750000  44399.050781
#
# [3933 rows x 2 columns]

# %%
#yetay ka tula bgh , practice kray la pahije

# %%
cdf.tail()
# Out:
#                       nf           bnf
# Date
# 2023-09-26  19664.699219  44624.199219
# 2023-09-27  19716.449219  44588.300781
# 2023-09-28  19523.550781  44300.949219
# 2023-09-29  19638.300781  44584.550781
# 2023-10-03  19528.750000  44399.050781

# %%
cdf[['nf','bnf']].corr()
# Out:
#            nf       bnf
# nf   1.000000  0.986873
# bnf  0.986873  1.000000

# %%
spread= log()

# %%
cdf['spread']= np.log(cdf['bnf']) - (np.log(cdf['nf']))
cdf
# Out:
#                       nf           bnf    spread       mean       std  \
# Date
# 2007-09-17   4494.649902   6897.100098  0.428213        NaN       NaN
# 2007-09-18   4546.200195   7059.649902  0.440104        NaN       NaN
# 2007-09-19   4732.350098   7401.850098  0.447308        NaN       NaN
# 2007-09-20   4747.549805   7390.149902  0.442519        NaN       NaN
# 2007-09-21   4837.549805   7464.500000  0.433750        NaN       NaN
# ...                  ...           ...       ...        ...       ...
# 2023-09-26  19664.699219  44624.199219  0.819451 -18.956588  0.028906
# 2023-09-27  19716.449219  44588.300781  0.816018 -18.959354  0.026461
# 2023-09-28  19523.550781  44300.949219  0.819385 -18.960636  0.024696
# 2023-09-29  19638.300781  44584.550781  0.819906 -18.962930  0.021095
# 2023-10-03  19528.750000  44399.050781  0.821330 -18.963691  0.019803
#
#              z-score
# Date
# 2007-09-17       NaN
# 2007-09-18       NaN
# 2007-09-19       NaN
# 2007-09-20       NaN
# 2007-09-21       NaN
# ...              ...
# 2023-09-26  0.099571
# 2023-09-27 -0.115055
# 2023-09-28  0.861159
# 2023-09-29  0.586005
# 2023-10-03  1.299588
#
# [3933 rows x 6 columns]

# %%
import plotly.express as px
fig = px.line(cdf.spread)
fig.show()

# %%
cdf['spread'].describe()
# Out:
# count    3660.000000
# mean        0.717009
# std         0.159138
# min         0.194385
# 25%         0.624866
# 50%         0.738429
# 75%         0.840369
# max         0.980175
# Name: spread, dtype: float64

# %%
cdf['mean']=cdf['spread'].rolling(20).mean()

cdf['std']=cdf['spread'].rolling(20).std()

# %%
cdf['z-score']=(cdf['spread']-cdf['mean'])/cdf['std']

# %%
cdf
# Out:
#                       nf           bnf    spread      mean       std   z-score
# Date
# 2007-09-17   4494.649902   6897.100098  0.428213       NaN       NaN       NaN
# 2007-09-18   4546.200195   7059.649902  0.440104       NaN       NaN       NaN
# 2007-09-19   4732.350098   7401.850098  0.447308       NaN       NaN       NaN
# 2007-09-20   4747.549805   7390.149902  0.442519       NaN       NaN       NaN
# 2007-09-21   4837.549805   7464.500000  0.433750       NaN       NaN       NaN
# ...                  ...           ...       ...       ...       ...       ...
# 2023-09-26  19664.699219  44624.199219  0.819451  0.823955  0.004195 -1.073532
# 2023-09-27  19716.449219  44588.300781  0.816018  0.823103  0.003972 -1.783413
# 2023-09-28  19523.550781  44300.949219  0.819385  0.822727  0.003950 -0.846196
# 2023-09-29  19638.300781  44584.550781  0.819906  0.822410  0.003907 -0.641065
# 2023-10-03  19528.750000  44399.050781  0.821330  0.822129  0.003762 -0.212217
#
# [3933 rows x 6 columns]

# %%
pnl =pd.DataFrame(columns=['Type','entry price','entry time','exit price','exit time','points','pnl'])
status = 0
entry_price=0
entry_time = 0
for row ,value in cdf.iterrows():
    if status==0 and value['z-score']>2:
        entry_price= value['bnd']
        entry_time = row
        status =1
        continue
    elif status ==1 and value['z-score']<1:
        pnl.loc[len(pnl)]=[' long bnf ', entry price, entry time, exit price,exit time,  points ,' pnl']
