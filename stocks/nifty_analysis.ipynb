# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = yf.download("^NSEI",period='max')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098  4732.350098
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805  4747.549805
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805  4837.549805
#
#             Volume
# Date
# 2007-09-17       0
# 2007-09-18       0
# 2007-09-19       0
# 2007-09-20       0
# 2007-09-21       0

# %%
daily_change=pd.DataFrame(columns=["date","change"])
daily_change["change"]=df["Close"]-df["Open"]
daily_change["date"]= df.index

# %%
daily_change.tail(10)
# Out:
#                  date      change
# Date
# 2023-09-18 2023-09-18  -22.648438
# 2023-09-20 2023-09-20  -79.349609
# 2023-09-21 2023-09-21  -98.201172
# 2023-09-22 2023-09-22  -70.599609
# 2023-09-25 2023-09-25   -3.648438
# 2023-09-26 2023-09-26  -18.101562
# 2023-09-27 2023-09-27   79.398438
# 2023-09-28 2023-09-28 -238.250000
# 2023-09-29 2023-09-29   57.101562
# 2023-10-03 2023-10-03  -93.650391

# %%
graph=daily_change.tail(20)

# %%
plt.plot(graph.index,graph["change"])
plt.grid(True)
plt.xticks(rotation=45)
# Out:
# (array([19605., 19609., 19613., 19617., 19621., 19625., 19629., 19631.]),
#  [Text(19605.0, 0, '2023-09-05'),
#   Text(19609.0, 0, '2023-09-09'),
#   Text(19613.0, 0, '2023-09-13'),
#   Text(19617.0, 0, '2023-09-17'),
#   Text(19621.0, 0, '2023-09-21'),
#   Text(19625.0, 0, '2023-09-25'),
#   Text(19629.0, 0, '2023-09-29'),
#   Text(19631.0, 0, '2023-10-01')])

# %%
import seaborn as sns

# %%
graph
# Out:
#                  date      change
# Date
# 2023-09-04 2023-09-04    3.750000
# 2023-09-05 2023-09-05   10.250000
# 2023-09-06 2023-09-06   29.851562
# 2023-09-07 2023-09-07  128.400391
# 2023-09-08 2023-09-08   45.148438
# 2023-09-11 2023-09-11  106.349609
# 2023-09-12 2023-09-12 -116.951172
# 2023-09-13 2023-09-13   80.500000
# 2023-09-14 2023-09-14  -24.849609
# 2023-09-15 2023-09-15   35.900391
# 2023-09-18 2023-09-18  -22.648438
# 2023-09-20 2023-09-20  -79.349609
# 2023-09-21 2023-09-21  -98.201172
# 2023-09-22 2023-09-22  -70.599609
# 2023-09-25 2023-09-25   -3.648438
# 2023-09-26 2023-09-26  -18.101562
# 2023-09-27 2023-09-27   79.398438
# 2023-09-28 2023-09-28 -238.250000
# 2023-09-29 2023-09-29   57.101562
# 2023-10-03 2023-10-03  -93.650391

# %%
sns.set(style="whitegrid")  # Set a grid background
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.figure(figsize=(20, 6))
sns.lineplot(data=df, x=graph["date"], y=graph["change"])

# Customize labels and title
plt.xlabel("change")
plt.ylabel("date")
plt.title('Line Plot with Seaborn')

# Show the legend
plt.legend()

# Rotate x-axis labels if necessary
plt.xticks(rotation=45)

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
